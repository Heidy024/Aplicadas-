# %% [markdown]
# <a href="https://colab.research.google.com/github/Heidy024/Aplicadas-/blob/main/puntos1_2)_1_8_13_1_3)_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# problems 1.2
#
# 1) a)$\frac{1}{3^{n}}$ desde n=0
# b) $\frac{1}{n}$
# c) $\frac {n+(n-1)}{n}$
# d)$\frac{(-1)^{n}}{2n+1}$ desde n=1

# %%
# punto 8) 1.2
import numpy as np
import matplotlib.pyplot as plt

n_max=50
def suc(n_max):
  a=[1]
  for n in range(1,n_max):
    a.append((1/3) * a[n-1])  # Aplicamos la regla recursiva
  return a

x=np.arange(1,n_max+1)



y= suc(n_max)


plt.plot(x,y)
plt.axhline(y=0,linestyle=":",color='r')#Sí hay asintota en cero debido a que por la sucesión recursiva aquí, el denominador siempre va a ser cada vez más grande lo que hace que la sucesión se acerca cada vez más a cero
plt.show()


print(y)
# Out:
# [1, 0.3333333333333333, 0.1111111111111111, 0.037037037037037035, 0.012345679012345678, 0.004115226337448559, 0.001371742112482853, 0.0004572473708276176, 0.00015241579027587253, 5.080526342529084e-05, 1.693508780843028e-05, 5.64502926947676e-06, 1.8816764231589197e-06, 6.272254743863065e-07, 2.0907515812876884e-07, 6.969171937625627e-08, 2.3230573125418757e-08, 7.743524375139585e-09, 2.581174791713195e-09, 8.603915972377316e-10, 2.867971990792439e-10, 9.559906635974796e-11, 3.186635545324932e-11, 1.0622118484416439e-11, 3.540706161472146e-12, 1.180235387157382e-12, 3.9341179571912734e-13, 1.311372652397091e-13, 4.3712421746569697e-14, 1.4570807248856565e-14, 4.856935749618854e-15, 1.6189785832062847e-15, 5.396595277354282e-16, 1.7988650924514273e-16, 5.99621697483809e-17, 1.9987389916126966e-17, 6.662463305375655e-18, 2.2208211017918848e-18, 7.402737005972949e-19, 2.467579001990983e-19, 8.225263339969942e-20, 2.741754446656647e-20, 9.13918148885549e-21, 3.0463938296184964e-21, 1.015464609872832e-21, 3.3848820329094397e-22, 1.1282940109698132e-22, 3.760980036566044e-23, 1.2536600121886813e-23, 4.178866707295604e-24]

# %% [markdown]
# Punto 13) 1.2
#
# sucesión 1 diverge a menos inifinito= $(-1)^{2n-1}\times n2$
# sucesión 2 diverge a más infinito= $n2$
#
# su suma da una sucesión que converge a cero.

# %%
###Gráfica
import numpy as np
import matplotlib.pyplot as plt
def punto12(n):
  return (((-1)**(2*n-1))*n*2)+(n*2)

x=np.arange(1,101)
y=[punto12(x) for x in x]
plt.plot(x,y)
plt.axhline(y=0,linestyle=":",color='r')
plt.show()

# %%
# punto 11 de 1.3
n=1 #harmonic series empieza en 1

sum_h_m=0

for n in range(1,1000):
  sum_h_m+=1/n
  if sum_h_m >= 5:
    break

print (n) #Da 83, se confirma con calculadora este resultado, así que se requiere la suma de la serie de n de 1 a 83 dentro de la formula de la harmonica.

while sum_h_m<5:
  sum_h_m+=1/n
  n+=1

print (n)
# Out:
# 83
# 83
